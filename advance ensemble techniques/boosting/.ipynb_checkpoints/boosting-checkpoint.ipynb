# %%
1. Bagging is a parallel learner process vs boosting is sequential.
2. Boosting is iterative vs bagging doesn't have to be.
3. Boosting can increase over-fitting whereas bagging generally decreases boosting.

Ensemble learning works well when different models make independent mistakes i.e. when different 
models make mistakes on different examples.

# %%
BOOSTING ALSO USE DECISION TREES

# %%
in BOOSTING:
--> hm apny dataset ki hr row ko weights dety hn and hr row ka weight same hota h phir 
hm apny dataset m s randomly rows ko pick krty hn and hr row ko pick krny ki probability same hoti h q k hr row
ka weight same hota h 

--> phir hm un selected rows pr ek model ko train krty hn then jab vo model
train ho jata h to hm phir pooorryy training data sets ko us model pr test krty hn, ab testing k doran is model n jin jin
rows ko ghalat predict kia un rows ka weight update kryn gy 

--> phir hm ek or model ko train kryn gy vesy hi randomly rows ko pick kr k but apn pichli ghalat predicted rows ka 
weight ziada h to un k select hony k chances ziada hn, yani ab hm kuch vhi rows jo ziad weight vali thi or kuch new rows
rows pr new model ko train kryn gy or phir baki poory training data pr us ko test kryn gy

--> ab is doosry valy model n jo rows ghlat predict ki un rows ka weight update kryn gy then hm phir teesra model pr un rows ko
train kryn gyn like above and process continue until the number of models that we want to train are achieved.

--> phir ab jo bhi predict krna hua us testing data ko hm hr hr weak models ko den gy(y jo uper valy models train kiye y
asal m weak models hn q k y mistakes kr rhyn hy) or un ki predictions ko classification k case m mode le kr and regression k
case m average le kr final outpuit consider kryn gy or y final output adal m strong model ki ho gi q k is strong model
ki output pichly saary weak models s mil kr bni

# %%
RANDOM FOREST M IN MODELS KO 'BASE MODELS' BOLA THA  UT YHAN HM IN KO WEAK LEARNERS/WEAK MODELS BOLYN GY

# %% [markdown]
# # TYPES

# %%
it include:
-------->>> ADA BOOST
-------->>> gradient BOOST
-------->>> XG BOOST
etc
