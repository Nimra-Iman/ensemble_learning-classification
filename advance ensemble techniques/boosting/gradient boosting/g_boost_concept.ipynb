# %%
IT FOLLOWS FOLLOWING STEPS:

# %%
from IPython.display import Image
Image(filename='dataset.png', width=300, height=300)

# %% [markdown]
# # STEP: 1

# %%
CREATE A BASE MODEL (without any training):
        ek base model bnayn gy jo k ko bhi row as input le ga to us ki output hmesha poory "y" column ki averge de ga
--> y column yani output column. 
e.: m n '2 , BE' pas kia is model ko or us n 75K output m predict kia

# %% [markdown]
# # STEP: 2

# %%
COMPUTE RESIDUALS, ERROR:
    yani base model n jo output di vo output actual s kitni different h

# %%
from IPython.display import Image
Image(filename='step 2.png', width=300, height=300)

# %% [markdown]
# # STEP: 3

# %%
CONSTRUCT A DT CONSIDER INPUT Xi AND OUTPUT R1:
    ab m n training dataset ki base pr DT construct kia jo k Xi (yani X1, X2) and R1 ki base pr bny ga, and jab m us
DT ko test kru gi test data (of course by using X1, X2), to jo mery pas output predict ki us DT n us ko m Predicted R1 
bol rhi , like below:

# %%
from IPython.display import Image
Image(filename='step 3.png', width=300, height=300)

# %%
----> ab mujy combine predicted output calculate krni h dono models ki, yani base model ki bhi and DT 
ki bhi, q k koi bhi input daala vo phly to base model predict kry ga then DT predict kry ga us ki output ko, but
hmy combine predicted output calculate krni h and it can be done like below:
            e.g: we have passed 1st row (2, BE) then base model will predict 75K (q k y base model to bs average deta)
and DT predict -23K so combined predicted value from both models will be: 75+(-23) = 52 and actual salary is 50, yani bhhhhttt
acha result a gya 1st time m hi but yhan problem ati h overfitting ki yani y 52 output jo ai y overfitting ka
shikaar h, yhan training pr to bhhtt acha result ay ga but testing pr bhht km,,,, is liye hm inhy direct
add nhi krty bl k alpha α parameter ko use krty hn

# %%
so combined predicted o/p will be: base_model_output + α (DT output)

--> α is learning rate having value 0.01 mostly but its value can range from 0 to 1.
so combimed predicted o/p will be: base_model_output + α (DT output) = 75 + 0.01(-23) = 74.77

-----> is α ki madad s hmara model slow learn kry ga, abhi first iteration h or gap ziada aya actuall value
jis ki (50) and predicted m which is (74), jesy jesy DT brhaty jayn gy y gap km hota jay ga and over fitting bhi 
km ho jay gi,, kabhi bhi first iteration m predicted actual k near nhi ani chahye

# %%
from IPython.display import Image
Image(filename='predicted_1st_iteration.png', width=300, height=300)

# %%
To ab hm iterations brhayn gy and next residual jo bny ga vo actuall and  Ŷ ka difference ho ga
e.g: for first row: R3 will be : 50 - 74.77 = 24.77

# %%
from IPython.display import Image
Image(filename='2nd_iteration_R3.png', width=300, height=300)

# %%
to ab jo next DT bny ga vo Xi( yani X1, X2) and R3 ko use kr k bny ga

# %%
from IPython.display import Image
Image(filename='2nd_iteration_dt2.png', width=300, height=300)

# %%
from IPython.display import Image
Image(filename='mathematical_form.png', width=300, height=300)

# %%
ho(x) is base model ki output and h1(x) is output of first DT and so on, DTs k saath α bhi use hua h but
base modle k saath koi α nhi h , is liye hm n α0 kr dia where α0 is 1

# %%
yhan regularization ki baat kryn:
        wesy regukarization m yhi hota h k hm loss function m ek reguklarization term ko add krty but yhan gradient
decscent m loss function m regularization term add nhi ki ja skti, yhan regularization just tree ki pruning kr k ya learning 
rate s      
but x_gboost m loss function m hi regularization term present hota h
